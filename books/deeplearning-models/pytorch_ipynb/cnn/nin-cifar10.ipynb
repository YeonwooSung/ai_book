# %% [markdown]
# Deep Learning Models -- A collection of various deep learning architectures, models, and tips for TensorFlow and PyTorch in Jupyter Notebooks.
# - Author: Sebastian Raschka
# - GitHub Repository: https://github.com/rasbt/deeplearning-models

# %%
# !pip install -q IPython
# !pip install -q ipykernel
# !pip install -q watermark
# !pip install -q matplotlib
# !pip install -q sklearn
# !pip install -q pandas
# !pip install -q pydot
# !pip install -q hiddenlayer
# !pip install -q graphviz

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch
# Out:
# Sebastian Raschka
#
# CPython 3.6.9
# IPython 5.5.0
#
# torch 1.5.1+cu101

# %% [markdown]
# # Network in Network CIFAR-10 Classifier

# %% [markdown]
# based on
#
# - Lin, Min, Qiang Chen, and Shuicheng Yan. "Network in network." arXiv preprint arXiv:1312.4400 (2013).

# %% [markdown]
# ## Imports

# %%
import os
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data import Subset

from torchvision import datasets
from torchvision import transforms

import matplotlib.pyplot as plt
from PIL import Image


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
torch.tensor([1]).device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Model Settings

# %%
##########################
### SETTINGS
##########################

# Hyperparameters
RANDOM_SEED = 1
LEARNING_RATE = 0.0005
BATCH_SIZE = 256
NUM_EPOCHS = 100

# Architecture
NUM_CLASSES = 10

# Other
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
GRAYSCALE = False

# %%
##########################
### CIFAR-10 Dataset
##########################


# Note transforms.ToTensor() scales input images
# to 0-1 range


train_indices = torch.arange(0, 49000)
valid_indices = torch.arange(49000, 50000)


train_and_valid = datasets.CIFAR10(root='data', 
                                   train=True, 
                                   transform=transforms.ToTensor(),
                                   download=True)

train_dataset = Subset(train_and_valid, train_indices)
valid_dataset = Subset(train_and_valid, valid_indices)


test_dataset = datasets.CIFAR10(root='data', 
                                train=False, 
                                transform=transforms.ToTensor())


#####################################################
### Data Loaders
#####################################################

train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE,
                          num_workers=8,
                          shuffle=True)

valid_loader = DataLoader(dataset=valid_dataset, 
                          batch_size=BATCH_SIZE,
                          num_workers=8,
                          shuffle=False)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE,
                         num_workers=8,
                         shuffle=False)

#####################################################

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break

for images, labels in test_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
    
for images, labels in valid_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/cifar-10-python.tar.gz to data
# Image batch dimensions: torch.Size([256, 3, 32, 32])
# Image label dimensions: torch.Size([256])
# Image batch dimensions: torch.Size([256, 3, 32, 32])
# Image label dimensions: torch.Size([256])
# Image batch dimensions: torch.Size([256, 3, 32, 32])
# Image label dimensions: torch.Size([256])

# %%
##########################
### MODEL
##########################


class NiN(nn.Module):
    def __init__(self, num_classes):
        super(NiN, self).__init__()
        self.num_classes = num_classes
        self.classifier = nn.Sequential(
                nn.Conv2d(3, 192, kernel_size=5, stride=1, padding=2),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 160, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.Conv2d(160,  96, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(96, 192, kernel_size=5, stride=1, padding=2),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
                nn.Dropout(0.5),

                nn.Conv2d(192, 192, kernel_size=3, stride=1, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(192, 192, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.Conv2d(192,  10, kernel_size=1, stride=1, padding=0),
                nn.ReLU(inplace=True),
                nn.AvgPool2d(kernel_size=8, stride=1, padding=0),

                )

    def forward(self, x):
        x = self.classifier(x)
        logits = x.view(x.size(0), self.num_classes)
        probas = torch.softmax(logits, dim=1)
        return logits, probas

# %% [markdown]
# ## Training without Pinned Memory

# %%
torch.manual_seed(RANDOM_SEED)

model = NiN(NUM_CLASSES)
model.to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
import hiddenlayer as hl
hl.build_graph(model, torch.zeros([25, 3, 32, 32]).to(DEVICE))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/onnx/symbolic_opset9.py:1310: UserWarning: Dropout is a training op and should not be exported in inference mode. Make sure to call eval() on the model, and to export it with param training=False.
#   warnings.warn("Dropout is a training op and should not be exported in inference mode. "

# %%
def compute_accuracy(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):
            
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100
    

start_time = time.time()
for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
    
        ### PREPARE MINIBATCH
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        cost.backward()
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 120:
            print (f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} | '
                   f'Batch {batch_idx:03d}/{len(train_loader):03d} |' 
                   f' Cost: {cost:.4f}')

    # no need to build the computation graph for backprop when computing accuracy
    with torch.set_grad_enabled(False):
        train_acc = compute_accuracy(model, train_loader, device=DEVICE)
        valid_acc = compute_accuracy(model, valid_loader, device=DEVICE)
        print(f'Epoch: {epoch+1:03d}/{NUM_EPOCHS:03d} Train Acc.: {train_acc:.2f}%'
              f' | Validation Acc.: {valid_acc:.2f}%')
        
    elapsed = (time.time() - start_time)/60
    print(f'Time elapsed: {elapsed:.2f} min')
  
elapsed = (time.time() - start_time)/60
print(f'Total Training Time: {elapsed:.2f} min')
# Out:
# Epoch: 001/100 | Batch 000/192 | Cost: 2.3043
# Epoch: 001/100 | Batch 120/192 | Cost: 2.0041
# Epoch: 001/100 Train Acc.: 24.18% | Validation Acc.: 27.00%
# Time elapsed: 0.35 min
# Epoch: 002/100 | Batch 000/192 | Cost: 1.9350
# Epoch: 002/100 | Batch 120/192 | Cost: 1.7446
# Epoch: 002/100 Train Acc.: 36.08% | Validation Acc.: 36.70%
# Time elapsed: 0.69 min
# Epoch: 003/100 | Batch 000/192 | Cost: 1.6324
# Epoch: 003/100 | Batch 120/192 | Cost: 1.6135
# Epoch: 003/100 Train Acc.: 41.75% | Validation Acc.: 42.50%
# Time elapsed: 1.04 min
# Epoch: 004/100 | Batch 000/192 | Cost: 1.5062
# Epoch: 004/100 | Batch 120/192 | Cost: 1.4272
# Epoch: 004/100 Train Acc.: 43.88% | Validation Acc.: 43.90%
# Time elapsed: 1.38 min
# Epoch: 005/100 | Batch 000/192 | Cost: 1.4328
# Epoch: 005/100 | Batch 120/192 | Cost: 1.4579
# Epoch: 005/100 Train Acc.: 49.44% | Validation Acc.: 48.30%
# Time elapsed: 1.72 min
# Epoch: 006/100 | Batch 000/192 | Cost: 1.3332
# Epoch: 006/100 | Batch 120/192 | Cost: 1.2475
# Epoch: 006/100 Train Acc.: 53.83% | Validation Acc.: 54.60%
# Time elapsed: 2.07 min
# Epoch: 007/100 | Batch 000/192 | Cost: 1.3004
# Epoch: 007/100 | Batch 120/192 | Cost: 1.1738
# Epoch: 007/100 Train Acc.: 56.48% | Validation Acc.: 56.30%
# Time elapsed: 2.41 min
# Epoch: 008/100 | Batch 000/192 | Cost: 1.1414
# Epoch: 008/100 | Batch 120/192 | Cost: 1.1363
# Epoch: 008/100 Train Acc.: 56.78% | Validation Acc.: 56.40%
# Time elapsed: 2.76 min
# Epoch: 009/100 | Batch 000/192 | Cost: 1.2452
# Epoch: 009/100 | Batch 120/192 | Cost: 1.0806
# Epoch: 009/100 Train Acc.: 59.56% | Validation Acc.: 62.10%
# Time elapsed: 3.11 min
# Epoch: 010/100 | Batch 000/192 | Cost: 1.0228
# Epoch: 010/100 | Batch 120/192 | Cost: 1.1042
# Epoch: 010/100 Train Acc.: 60.55% | Validation Acc.: 63.40%
# Time elapsed: 3.45 min
# Epoch: 011/100 | Batch 000/192 | Cost: 1.0565
# Epoch: 011/100 | Batch 120/192 | Cost: 1.0033
# Epoch: 011/100 Train Acc.: 61.82% | Validation Acc.: 61.00%
# Time elapsed: 3.79 min
# Epoch: 012/100 | Batch 000/192 | Cost: 1.0023
# Epoch: 012/100 | Batch 120/192 | Cost: 1.1402
# Epoch: 012/100 Train Acc.: 63.87% | Validation Acc.: 63.80%
# Time elapsed: 4.14 min
# Epoch: 013/100 | Batch 000/192 | Cost: 0.8760
# Epoch: 013/100 | Batch 120/192 | Cost: 0.9804
# Epoch: 013/100 Train Acc.: 63.73% | Validation Acc.: 62.80%
# Time elapsed: 4.48 min
# Epoch: 014/100 | Batch 000/192 | Cost: 0.9027
# Epoch: 014/100 | Batch 120/192 | Cost: 1.1282
# Epoch: 014/100 Train Acc.: 66.42% | Validation Acc.: 66.30%
# Time elapsed: 4.83 min
# Epoch: 015/100 | Batch 000/192 | Cost: 0.8892
# Epoch: 015/100 | Batch 120/192 | Cost: 0.9479
# Epoch: 015/100 Train Acc.: 65.14% | Validation Acc.: 65.90%
# Time elapsed: 5.17 min
# Epoch: 016/100 | Batch 000/192 | Cost: 0.8575
# Epoch: 016/100 | Batch 120/192 | Cost: 0.9928
# Epoch: 016/100 Train Acc.: 66.79% | Validation Acc.: 65.50%
# Time elapsed: 5.52 min
# Epoch: 017/100 | Batch 000/192 | Cost: 0.8890
# Epoch: 017/100 | Batch 120/192 | Cost: 0.9584
# Epoch: 017/100 Train Acc.: 69.32% | Validation Acc.: 68.50%
# Time elapsed: 5.86 min
# Epoch: 018/100 | Batch 000/192 | Cost: 0.8710
# Epoch: 018/100 | Batch 120/192 | Cost: 0.8033
# Epoch: 018/100 Train Acc.: 69.13% | Validation Acc.: 68.10%
# Time elapsed: 6.21 min
# Epoch: 019/100 | Batch 000/192 | Cost: 0.9469
# Epoch: 019/100 | Batch 120/192 | Cost: 0.9746
# Epoch: 019/100 Train Acc.: 70.75% | Validation Acc.: 69.20%
# Time elapsed: 6.55 min
# Epoch: 020/100 | Batch 000/192 | Cost: 0.8509
# Epoch: 020/100 | Batch 120/192 | Cost: 0.8083
# Epoch: 020/100 Train Acc.: 71.13% | Validation Acc.: 71.40%
# Time elapsed: 6.89 min
# Epoch: 021/100 | Batch 000/192 | Cost: 0.8532
# Epoch: 021/100 | Batch 120/192 | Cost: 0.8372
# Epoch: 021/100 Train Acc.: 71.29% | Validation Acc.: 69.70%
# Time elapsed: 7.24 min
# Epoch: 022/100 | Batch 000/192 | Cost: 0.7992
# Epoch: 022/100 | Batch 120/192 | Cost: 0.6424
# Epoch: 022/100 Train Acc.: 71.69% | Validation Acc.: 70.30%
# Time elapsed: 7.58 min
# Epoch: 023/100 | Batch 000/192 | Cost: 0.8724
# Epoch: 023/100 | Batch 120/192 | Cost: 0.8339
# Epoch: 023/100 Train Acc.: 72.01% | Validation Acc.: 69.90%
# Time elapsed: 7.93 min
# Epoch: 024/100 | Batch 000/192 | Cost: 0.7950
# Epoch: 024/100 | Batch 120/192 | Cost: 0.7528
# Epoch: 024/100 Train Acc.: 73.46% | Validation Acc.: 72.30%
# Time elapsed: 8.27 min
# Epoch: 025/100 | Batch 000/192 | Cost: 0.7893
# Epoch: 025/100 | Batch 120/192 | Cost: 0.6749
# Epoch: 025/100 Train Acc.: 74.21% | Validation Acc.: 71.80%
# Time elapsed: 8.62 min
# Epoch: 026/100 | Batch 000/192 | Cost: 0.6514
# Epoch: 026/100 | Batch 120/192 | Cost: 0.7255
# Epoch: 026/100 Train Acc.: 73.04% | Validation Acc.: 72.20%
# Time elapsed: 8.96 min
# Epoch: 027/100 | Batch 000/192 | Cost: 0.7122
# Epoch: 027/100 | Batch 120/192 | Cost: 0.6967
# Epoch: 027/100 Train Acc.: 75.32% | Validation Acc.: 74.30%
# Time elapsed: 9.30 min
# Epoch: 028/100 | Batch 000/192 | Cost: 0.6683
# Epoch: 028/100 | Batch 120/192 | Cost: 0.6337
# Epoch: 028/100 Train Acc.: 76.00% | Validation Acc.: 73.60%
# Time elapsed: 9.65 min
# Epoch: 029/100 | Batch 000/192 | Cost: 0.7235
# Epoch: 029/100 | Batch 120/192 | Cost: 0.6535
# Epoch: 029/100 Train Acc.: 76.30% | Validation Acc.: 74.90%
# Time elapsed: 9.99 min
# Epoch: 030/100 | Batch 000/192 | Cost: 0.7498
# Epoch: 030/100 | Batch 120/192 | Cost: 0.6587
# Epoch: 030/100 Train Acc.: 76.64% | Validation Acc.: 74.40%
# Time elapsed: 10.34 min
# Epoch: 031/100 | Batch 000/192 | Cost: 0.6098
# Epoch: 031/100 | Batch 120/192 | Cost: 0.5858
# Epoch: 031/100 Train Acc.: 75.52% | Validation Acc.: 74.20%
# Time elapsed: 10.68 min
# Epoch: 032/100 | Batch 000/192 | Cost: 0.6672
# Epoch: 032/100 | Batch 120/192 | Cost: 0.7482
# Epoch: 032/100 Train Acc.: 77.17% | Validation Acc.: 73.90%
# Time elapsed: 11.03 min
# Epoch: 033/100 | Batch 000/192 | Cost: 0.7271
# Epoch: 033/100 | Batch 120/192 | Cost: 0.7013
# Epoch: 033/100 Train Acc.: 77.68% | Validation Acc.: 75.00%
# Time elapsed: 11.37 min
# Epoch: 034/100 | Batch 000/192 | Cost: 0.5911
# Epoch: 034/100 | Batch 120/192 | Cost: 0.6259
# Epoch: 034/100 Train Acc.: 77.92% | Validation Acc.: 73.70%
# Time elapsed: 11.72 min
# Epoch: 035/100 | Batch 000/192 | Cost: 0.6155
# Epoch: 035/100 | Batch 120/192 | Cost: 0.7030
# Epoch: 035/100 Train Acc.: 79.51% | Validation Acc.: 75.70%
# Time elapsed: 12.07 min
# Epoch: 036/100 | Batch 000/192 | Cost: 0.6942
# Epoch: 036/100 | Batch 120/192 | Cost: 0.6422
# Epoch: 036/100 Train Acc.: 79.58% | Validation Acc.: 75.90%
# Time elapsed: 12.41 min
# Epoch: 037/100 | Batch 000/192 | Cost: 0.6403
# Epoch: 037/100 | Batch 120/192 | Cost: 0.6027
# Epoch: 037/100 Train Acc.: 79.19% | Validation Acc.: 77.70%
# Time elapsed: 12.76 min
# Epoch: 038/100 | Batch 000/192 | Cost: 0.5637
# Epoch: 038/100 | Batch 120/192 | Cost: 0.5646
# Epoch: 038/100 Train Acc.: 79.34% | Validation Acc.: 76.70%
# Time elapsed: 13.10 min
# Epoch: 039/100 | Batch 000/192 | Cost: 0.5208
# Epoch: 039/100 | Batch 120/192 | Cost: 0.5630
# Epoch: 039/100 Train Acc.: 79.13% | Validation Acc.: 76.80%
# Time elapsed: 13.44 min
# Epoch: 040/100 | Batch 000/192 | Cost: 0.6377
# Epoch: 040/100 | Batch 120/192 | Cost: 0.5755
# Epoch: 040/100 Train Acc.: 80.89% | Validation Acc.: 77.00%
# Time elapsed: 13.79 min
# Epoch: 041/100 | Batch 000/192 | Cost: 0.5138
# Epoch: 041/100 | Batch 120/192 | Cost: 0.7050
# Epoch: 041/100 Train Acc.: 80.64% | Validation Acc.: 75.10%
# Time elapsed: 14.13 min
# Epoch: 042/100 | Batch 000/192 | Cost: 0.4783
# Epoch: 042/100 | Batch 120/192 | Cost: 0.6303
# Epoch: 042/100 Train Acc.: 81.08% | Validation Acc.: 78.90%
# Time elapsed: 14.48 min
# Epoch: 043/100 | Batch 000/192 | Cost: 0.4734
# Epoch: 043/100 | Batch 120/192 | Cost: 0.4774
# Epoch: 043/100 Train Acc.: 81.57% | Validation Acc.: 76.50%
# Time elapsed: 14.83 min
# Epoch: 044/100 | Batch 000/192 | Cost: 0.5157
# Epoch: 044/100 | Batch 120/192 | Cost: 0.5578
# Epoch: 044/100 Train Acc.: 81.04% | Validation Acc.: 78.40%
# Time elapsed: 15.17 min
# Epoch: 045/100 | Batch 000/192 | Cost: 0.5093
# Epoch: 045/100 | Batch 120/192 | Cost: 0.6032
# Epoch: 045/100 Train Acc.: 82.74% | Validation Acc.: 78.30%
# Time elapsed: 15.52 min
# Epoch: 046/100 | Batch 000/192 | Cost: 0.4896
# Epoch: 046/100 | Batch 120/192 | Cost: 0.4682
# Epoch: 046/100 Train Acc.: 82.58% | Validation Acc.: 77.40%
# Time elapsed: 15.86 min
# Epoch: 047/100 | Batch 000/192 | Cost: 0.4972
# Epoch: 047/100 | Batch 120/192 | Cost: 0.4998
# Epoch: 047/100 Train Acc.: 82.84% | Validation Acc.: 78.90%
# Time elapsed: 16.21 min
# Epoch: 048/100 | Batch 000/192 | Cost: 0.4225
# Epoch: 048/100 | Batch 120/192 | Cost: 0.6129
# Epoch: 048/100 Train Acc.: 82.92% | Validation Acc.: 77.30%
# Time elapsed: 16.55 min
# Epoch: 049/100 | Batch 000/192 | Cost: 0.4496
# Epoch: 049/100 | Batch 120/192 | Cost: 0.4332
# Epoch: 049/100 Train Acc.: 83.66% | Validation Acc.: 78.40%
# Time elapsed: 16.90 min
# Epoch: 050/100 | Batch 000/192 | Cost: 0.5423
# Epoch: 050/100 | Batch 120/192 | Cost: 0.5665
# Epoch: 050/100 Train Acc.: 83.84% | Validation Acc.: 79.00%
# Time elapsed: 17.24 min
# Epoch: 051/100 | Batch 000/192 | Cost: 0.4372
# Epoch: 051/100 | Batch 120/192 | Cost: 0.4252
# Epoch: 051/100 Train Acc.: 83.27% | Validation Acc.: 79.80%
# Time elapsed: 17.58 min
# Epoch: 052/100 | Batch 000/192 | Cost: 0.5137
# Epoch: 052/100 | Batch 120/192 | Cost: 0.5231
# Epoch: 052/100 Train Acc.: 83.68% | Validation Acc.: 78.10%
# Time elapsed: 17.93 min
# Epoch: 053/100 | Batch 000/192 | Cost: 0.5262
# Epoch: 053/100 | Batch 120/192 | Cost: 0.3709
# Epoch: 053/100 Train Acc.: 82.26% | Validation Acc.: 77.40%
# Time elapsed: 18.27 min
# Epoch: 054/100 | Batch 000/192 | Cost: 0.4764
# Epoch: 054/100 | Batch 120/192 | Cost: 0.5095
# Epoch: 054/100 Train Acc.: 83.71% | Validation Acc.: 77.60%
# Time elapsed: 18.62 min
# Epoch: 055/100 | Batch 000/192 | Cost: 0.4363
# Epoch: 055/100 | Batch 120/192 | Cost: 0.4260
# Epoch: 055/100 Train Acc.: 83.07% | Validation Acc.: 78.10%
# Time elapsed: 18.96 min
# Epoch: 056/100 | Batch 000/192 | Cost: 0.5525
# Epoch: 056/100 | Batch 120/192 | Cost: 0.3717
# Epoch: 056/100 Train Acc.: 84.69% | Validation Acc.: 78.20%
# Time elapsed: 19.31 min
# Epoch: 057/100 | Batch 000/192 | Cost: 0.3486
# Epoch: 057/100 | Batch 120/192 | Cost: 0.4213
# Epoch: 057/100 Train Acc.: 84.81% | Validation Acc.: 79.00%
# Time elapsed: 19.65 min
# Epoch: 058/100 | Batch 000/192 | Cost: 0.3746
# Epoch: 058/100 | Batch 120/192 | Cost: 0.3970
# Epoch: 058/100 Train Acc.: 85.43% | Validation Acc.: 79.30%
# Time elapsed: 20.00 min
# Epoch: 059/100 | Batch 000/192 | Cost: 0.4380
# Epoch: 059/100 | Batch 120/192 | Cost: 0.4323
# Epoch: 059/100 Train Acc.: 85.17% | Validation Acc.: 79.20%
# Time elapsed: 20.34 min
# Epoch: 060/100 | Batch 000/192 | Cost: 0.2895
# Epoch: 060/100 | Batch 120/192 | Cost: 0.4876
# Epoch: 060/100 Train Acc.: 86.06% | Validation Acc.: 80.00%
# Time elapsed: 20.68 min
# Epoch: 061/100 | Batch 000/192 | Cost: 0.4768
# Epoch: 061/100 | Batch 120/192 | Cost: 0.3555
# Epoch: 061/100 Train Acc.: 86.73% | Validation Acc.: 80.40%
# Time elapsed: 21.03 min
# Epoch: 062/100 | Batch 000/192 | Cost: 0.4041
# Epoch: 062/100 | Batch 120/192 | Cost: 0.2696
# Epoch: 062/100 Train Acc.: 86.88% | Validation Acc.: 80.00%
# Time elapsed: 21.37 min
# Epoch: 063/100 | Batch 000/192 | Cost: 0.3945
# Epoch: 063/100 | Batch 120/192 | Cost: 0.5223
# Epoch: 063/100 Train Acc.: 86.07% | Validation Acc.: 80.40%
# Time elapsed: 21.72 min
# Epoch: 064/100 | Batch 000/192 | Cost: 0.3680
# Epoch: 064/100 | Batch 120/192 | Cost: 0.3739
# Epoch: 064/100 Train Acc.: 87.35% | Validation Acc.: 81.20%
# Time elapsed: 22.06 min
# Epoch: 065/100 | Batch 000/192 | Cost: 0.3576
# Epoch: 065/100 | Batch 120/192 | Cost: 0.4235
# Epoch: 065/100 Train Acc.: 85.52% | Validation Acc.: 77.30%
# Time elapsed: 22.41 min
# Epoch: 066/100 | Batch 000/192 | Cost: 0.3803
# Epoch: 066/100 | Batch 120/192 | Cost: 0.4552
# Epoch: 066/100 Train Acc.: 87.29% | Validation Acc.: 79.50%
# Time elapsed: 22.75 min
# Epoch: 067/100 | Batch 000/192 | Cost: 0.3927
# Epoch: 067/100 | Batch 120/192 | Cost: 0.3092
# Epoch: 067/100 Train Acc.: 85.73% | Validation Acc.: 79.00%
# Time elapsed: 23.10 min
# Epoch: 068/100 | Batch 000/192 | Cost: 0.4226
# Epoch: 068/100 | Batch 120/192 | Cost: 0.2751
# Epoch: 068/100 Train Acc.: 87.38% | Validation Acc.: 79.60%
# Time elapsed: 23.44 min
# Epoch: 069/100 | Batch 000/192 | Cost: 0.4338
# Epoch: 069/100 | Batch 120/192 | Cost: 0.4057
# Epoch: 069/100 Train Acc.: 87.81% | Validation Acc.: 81.30%
# Time elapsed: 23.79 min
# Epoch: 070/100 | Batch 000/192 | Cost: 0.2754
# Epoch: 070/100 | Batch 120/192 | Cost: 0.3225
# Epoch: 070/100 Train Acc.: 88.06% | Validation Acc.: 79.30%
# Time elapsed: 24.13 min
# Epoch: 071/100 | Batch 000/192 | Cost: 0.3481
# Epoch: 071/100 | Batch 120/192 | Cost: 0.2608
# Epoch: 071/100 Train Acc.: 87.96% | Validation Acc.: 80.70%
# Time elapsed: 24.47 min
# Epoch: 072/100 | Batch 000/192 | Cost: 0.3075
# Epoch: 072/100 | Batch 120/192 | Cost: 0.4370
# Epoch: 072/100 Train Acc.: 88.27% | Validation Acc.: 80.00%
# Time elapsed: 24.82 min
# Epoch: 073/100 | Batch 000/192 | Cost: 0.3717
# Epoch: 073/100 | Batch 120/192 | Cost: 0.4243
# Epoch: 073/100 Train Acc.: 88.51% | Validation Acc.: 80.40%
# Time elapsed: 25.16 min
# Epoch: 074/100 | Batch 000/192 | Cost: 0.3309
# Epoch: 074/100 | Batch 120/192 | Cost: 0.2892
# Epoch: 074/100 Train Acc.: 88.29% | Validation Acc.: 79.40%
# Time elapsed: 25.51 min
# Epoch: 075/100 | Batch 000/192 | Cost: 0.2358
# Epoch: 075/100 | Batch 120/192 | Cost: 0.3298
# Epoch: 075/100 Train Acc.: 88.92% | Validation Acc.: 81.10%
# Time elapsed: 25.85 min
# Epoch: 076/100 | Batch 000/192 | Cost: 0.2908
# Epoch: 076/100 | Batch 120/192 | Cost: 0.2683
# Epoch: 076/100 Train Acc.: 88.92% | Validation Acc.: 80.20%
# Time elapsed: 26.20 min
# Epoch: 077/100 | Batch 000/192 | Cost: 0.2659
# Epoch: 077/100 | Batch 120/192 | Cost: 0.4185
# Epoch: 077/100 Train Acc.: 89.90% | Validation Acc.: 81.10%
# Time elapsed: 26.54 min
# Epoch: 078/100 | Batch 000/192 | Cost: 0.2309
# Epoch: 078/100 | Batch 120/192 | Cost: 0.3875
# Epoch: 078/100 Train Acc.: 89.88% | Validation Acc.: 81.50%
# Time elapsed: 26.89 min
# Epoch: 079/100 | Batch 000/192 | Cost: 0.2501
# Epoch: 079/100 | Batch 120/192 | Cost: 0.2655
# Epoch: 079/100 Train Acc.: 89.75% | Validation Acc.: 80.10%
# Time elapsed: 27.23 min
# Epoch: 080/100 | Batch 000/192 | Cost: 0.2901
# Epoch: 080/100 | Batch 120/192 | Cost: 0.3772
# Epoch: 080/100 Train Acc.: 89.28% | Validation Acc.: 80.20%
# Time elapsed: 27.58 min
# Epoch: 081/100 | Batch 000/192 | Cost: 0.2804
# Epoch: 081/100 | Batch 120/192 | Cost: 0.3445
# Epoch: 081/100 Train Acc.: 88.92% | Validation Acc.: 79.80%
# Time elapsed: 27.92 min
# Epoch: 082/100 | Batch 000/192 | Cost: 0.3334
# Epoch: 082/100 | Batch 120/192 | Cost: 0.2989
# Epoch: 082/100 Train Acc.: 88.80% | Validation Acc.: 79.10%
# Time elapsed: 28.27 min
# Epoch: 083/100 | Batch 000/192 | Cost: 0.2613
# Epoch: 083/100 | Batch 120/192 | Cost: 0.3674
# Epoch: 083/100 Train Acc.: 90.38% | Validation Acc.: 81.10%
# Time elapsed: 28.61 min
# Epoch: 084/100 | Batch 000/192 | Cost: 0.2914
# Epoch: 084/100 | Batch 120/192 | Cost: 0.2686
# Epoch: 084/100 Train Acc.: 88.18% | Validation Acc.: 79.30%
# Time elapsed: 28.96 min
# Epoch: 085/100 | Batch 000/192 | Cost: 0.2974
# Epoch: 085/100 | Batch 120/192 | Cost: 0.3652
# Epoch: 085/100 Train Acc.: 91.11% | Validation Acc.: 81.10%
# Time elapsed: 29.30 min
# Epoch: 086/100 | Batch 000/192 | Cost: 0.2652
# Epoch: 086/100 | Batch 120/192 | Cost: 0.3336
# Epoch: 086/100 Train Acc.: 90.83% | Validation Acc.: 80.70%
# Time elapsed: 29.65 min
# Epoch: 087/100 | Batch 000/192 | Cost: 0.2700
# Epoch: 087/100 | Batch 120/192 | Cost: 0.2431
# Epoch: 087/100 Train Acc.: 90.62% | Validation Acc.: 81.60%
# Time elapsed: 29.99 min
# Epoch: 088/100 | Batch 000/192 | Cost: 0.2632
# Epoch: 088/100 | Batch 120/192 | Cost: 0.2094
# Epoch: 088/100 Train Acc.: 89.47% | Validation Acc.: 80.60%
# Time elapsed: 30.34 min
# Epoch: 089/100 | Batch 000/192 | Cost: 0.3107
# Epoch: 089/100 | Batch 120/192 | Cost: 0.2491
# Epoch: 089/100 Train Acc.: 91.47% | Validation Acc.: 80.60%
# Time elapsed: 30.68 min
# Epoch: 090/100 | Batch 000/192 | Cost: 0.1940
# Epoch: 090/100 | Batch 120/192 | Cost: 0.2782
# Epoch: 090/100 Train Acc.: 90.34% | Validation Acc.: 80.90%
# Time elapsed: 31.02 min
# Epoch: 091/100 | Batch 000/192 | Cost: 0.2669
# Epoch: 091/100 | Batch 120/192 | Cost: 0.3550
# Epoch: 091/100 Train Acc.: 91.09% | Validation Acc.: 80.00%
# Time elapsed: 31.37 min
# Epoch: 092/100 | Batch 000/192 | Cost: 0.2262
# Epoch: 092/100 | Batch 120/192 | Cost: 0.2175
# Epoch: 092/100 Train Acc.: 92.32% | Validation Acc.: 81.80%
# Time elapsed: 31.71 min
# Epoch: 093/100 | Batch 000/192 | Cost: 0.1634
# Epoch: 093/100 | Batch 120/192 | Cost: 0.2062
# Epoch: 093/100 Train Acc.: 91.18% | Validation Acc.: 81.20%
# Time elapsed: 32.06 min
# Epoch: 094/100 | Batch 000/192 | Cost: 0.2585
# Epoch: 094/100 | Batch 120/192 | Cost: 0.3068
# Epoch: 094/100 Train Acc.: 91.94% | Validation Acc.: 80.60%
# Time elapsed: 32.40 min
# Epoch: 095/100 | Batch 000/192 | Cost: 0.2778
# Epoch: 095/100 | Batch 120/192 | Cost: 0.3047
# Epoch: 095/100 Train Acc.: 91.51% | Validation Acc.: 80.60%
# Time elapsed: 32.74 min
# Epoch: 096/100 | Batch 000/192 | Cost: 0.2717
# Epoch: 096/100 | Batch 120/192 | Cost: 0.2376
# Epoch: 096/100 Train Acc.: 91.56% | Validation Acc.: 82.00%
# Time elapsed: 33.09 min
# Epoch: 097/100 | Batch 000/192 | Cost: 0.1985
# Epoch: 097/100 | Batch 120/192 | Cost: 0.2482
# Epoch: 097/100 Train Acc.: 90.97% | Validation Acc.: 80.00%
# Time elapsed: 33.44 min
# Epoch: 098/100 | Batch 000/192 | Cost: 0.2598
# Epoch: 098/100 | Batch 120/192 | Cost: 0.3135
# Epoch: 098/100 Train Acc.: 91.84% | Validation Acc.: 80.30%
# Time elapsed: 33.78 min
# Epoch: 099/100 | Batch 000/192 | Cost: 0.2027
# Epoch: 099/100 | Batch 120/192 | Cost: 0.2253
# Epoch: 099/100 Train Acc.: 91.41% | Validation Acc.: 80.80%
# Time elapsed: 34.12 min
# Epoch: 100/100 | Batch 000/192 | Cost: 0.2435
# Epoch: 100/100 | Batch 120/192 | Cost: 0.2352
# Epoch: 100/100 Train Acc.: 90.86% | Validation Acc.: 81.00%
# Time elapsed: 34.47 min
# Total Training Time: 34.47 min

# %%
# %watermark -iv
# Out:
# numpy     1.18.5
# PIL.Image 7.0.0
# torch     1.5.1+cu101
# pandas    1.0.5
